# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./datasets/sales_data_sample.csv', encoding='unicode_escape')

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %%
# pehle thoda preprocessing karte hai

# drop unnecessary columns
drop_columns = ['CUSTOMERNAME', 'PHONE', 'ADDRESSLINE1', 'ADDRESSLINE2','POSTALCODE','TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME']
df.drop(drop_columns, axis=1, inplace=True)

# %%
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP  \
# ...

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CITY', 'STATE', 'COUNTRY',
#        'DEALSIZE'],
#       dtype='object')

# %%
# check whether there are any null values
df.isnull().sum()
# Out:
# ORDERNUMBER           0
# QUANTITYORDERED       0
# PRICEEACH             0
# ORDERLINENUMBER       0
# SALES                 0
# ORDERDATE             0
# STATUS                0
# QTR_ID                0
# MONTH_ID              0
# YEAR_ID               0
# PRODUCTLINE           0
# MSRP                  0
# PRODUCTCODE           0
# CITY                  0
# STATE              1486
# COUNTRY               0
# DEALSIZE              0
# dtype: int64

# %%
df.shape
# Out:
# (2823, 17)

# %%
# dropping STATE, CITY column
df.drop(['STATE','CITY'], axis=1, inplace=True)

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER        0
# QUANTITYORDERED    0
# PRICEEACH          0
# ORDERLINENUMBER    0
# SALES              0
# ORDERDATE          0
# STATUS             0
# QTR_ID             0
# MONTH_ID           0
# YEAR_ID            0
# PRODUCTLINE        0
# MSRP               0
# PRODUCTCODE        0
# COUNTRY            0
# DEALSIZE           0
# dtype: int64

# %%
# Since k means only works on numerical data, we need to convert categorical data to numerical data
# Let's check the data types of each column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ORDERNUMBER      2823 non-null   int64
#  1   QUANTITYORDERED  2823 non-null   int64
#  2   PRICEEACH        2823 non-null   float64
#  3   ORDERLINENUMBER  2823 non-null   int64
#  4   SALES            2823 non-null   float64
#  5   ORDERDATE        2823 non-null   object
#  6   STATUS           2823 non-null   object
#  7   QTR_ID           2823 non-null   int64
#  8   MONTH_ID         2823 non-null   int64
#  9   YEAR_ID          2823 non-null   int64
#  10  PRODUCTLINE      2823 non-null   object
#  11  MSRP             2823 non-null   int64
#  12  PRODUCTCODE      2823 non-null   object
#  13  COUNTRY          2823 non-null   object
#  14  DEALSIZE         2823 non-null   object
# dtypes: float64(2), int64(7), object(6)
# memory usage: 330.9+ KB

# %%
# using get dummies, we can convert categorical data to numerical data
# country and productline ko get dummies se convert in numerical data
df = pd.get_dummies(df, columns=['COUNTRY', 'PRODUCTLINE'], dtype=int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 39 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ORDERNUMBER                   2823 non-null   int64
#  1   QUANTITYORDERED               2823 non-null   int64
#  2   PRICEEACH                     2823 non-null   float64
#  3   ORDERLINENUMBER               2823 non-null   int64
#  4   SALES                         2823 non-null   float64
#  5   ORDERDATE                     2823 non-null   object
#  6   STATUS                        2823 non-null   object
#  7   QTR_ID                        2823 non-null   int64
#  8   MONTH_ID                      2823 non-null   int64
#  9   YEAR_ID                       2823 non-null   int64
#  10  MSRP                          2823 non-null   int64
#  11  PRODUCTCODE                   2823 non-null   object
# ...

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#    COUNTRY_Switzerland COUNTRY_UK COUNTRY_USA  PRODUCTLINE_Classic Cars  \
# 0                    0          0           1                         0
# ...

# %%
# product code, status me bohot se unique values the isliye we dont use get_dummies on them

# dealsize -> small, medium, large, Here we use label encoding to convert categorical data to numerical data
from sklearn.preprocessing import LabelEncoder
le_obj = LabelEncoder()
df['DEALSIZE'] = le_obj.fit_transform(df['DEALSIZE'])

df['DEALSIZE'].unique()
# Out:
# array([2, 1, 0])

# %%
# df['PRODUCTCODE'].unique()

# apply label encoding on product code as well
df['PRODUCTCODE'] = le_obj.fit_transform(df['PRODUCTCODE'])

df['PRODUCTCODE']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#        ...
# 2818    108
# 2819    108
# 2820    108
# 2821    108
# 2822    108
# Name: PRODUCTCODE, Length: 2823, dtype: int32

# %%
df['STATUS'].unique()
# Out:
# array(['Shipped', 'Disputed', 'In Process', 'Cancelled', 'On Hold',
#        'Resolved'], dtype=object)

# %%
# apply label encoding on status as well
# Assigning 1 for success, 2 for issues, 0 for in progress
df['STATUS'] = df['STATUS'].map({
    'Shipped': 1,
    'Disputed': 2,
    'Cancelled': 2,
    'Resolved': 1,
    'On Hold': 2,
    'In Process': 0
})

df['STATUS']
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 2818    1
# 2819    1
# 2820    1
# 2821    1
# 2822    2
# Name: STATUS, Length: 2823, dtype: int64

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE  STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00       1       1         2     2003  ...
# 1    5/7/2003 0:00       1       2         5     2003  ...
# 2    7/1/2003 0:00       1       3         7     2003  ...
# 3   8/25/2003 0:00       1       3         8     2003  ...
# 4  10/10/2003 0:00       1       4        10     2003  ...
#
#    COUNTRY_Switzerland  COUNTRY_UK  COUNTRY_USA  PRODUCTLINE_Classic Cars  \
# 0                    0           0            1                         0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 39 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ORDERNUMBER                   2823 non-null   int64
#  1   QUANTITYORDERED               2823 non-null   int64
#  2   PRICEEACH                     2823 non-null   float64
#  3   ORDERLINENUMBER               2823 non-null   int64
#  4   SALES                         2823 non-null   float64
#  5   ORDERDATE                     2823 non-null   object
#  6   STATUS                        2823 non-null   int64
#  7   QTR_ID                        2823 non-null   int64
#  8   MONTH_ID                      2823 non-null   int64
#  9   YEAR_ID                       2823 non-null   int64
#  10  MSRP                          2823 non-null   int64
#  11  PRODUCTCODE                   2823 non-null   int32
# ...

# %%
# orderdate is still object -> convert it to int
# object -> datetime -> int 
df['ORDERDATE'] = pd.to_datetime(df['ORDERDATE'])
df['ORDERDATE'] = pd.to_numeric(df['ORDERDATE']).astype(int) / 10**9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 39 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ORDERNUMBER                   2823 non-null   int64
#  1   QUANTITYORDERED               2823 non-null   int64
#  2   PRICEEACH                     2823 non-null   float64
#  3   ORDERLINENUMBER               2823 non-null   int64
#  4   SALES                         2823 non-null   float64
#  5   ORDERDATE                     2823 non-null   float64
#  6   STATUS                        2823 non-null   int64
#  7   QTR_ID                        2823 non-null   int64
#  8   MONTH_ID                      2823 non-null   int64
#  9   YEAR_ID                       2823 non-null   int64
#  10  MSRP                          2823 non-null   int64
#  11  PRODUCTCODE                   2823 non-null   int32
# ...

# %%
df['ORDERDATE']
# Out:
# 0       0.321192
# 1      -0.245563
# 2       0.693502
# 3       1.632567
# 4       2.105606
#           ...
# 2818    1.372455
# 2819    1.615987
# 2820   -0.700121
# 2821    0.697958
# 2822    1.285751
# Name: ORDERDATE, Length: 2823, dtype: float64

# %%
# Now we have converted all the columns to numerical data

# jab bhi zyada correlation raha between 2 columns to model overfit hojata
# so we need to remove one of them
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))

# taking only first 10 columns

sns.heatmap(df.iloc[:, :12].corr(), annot=True)
# Out:
# <Axes: >

# %%
# jinka zyada correlation hai unko remove karna hai
# year_id and ordernumber & month_id and Qtr_id
# remove year_id and qtr_id
df.drop(['YEAR_ID','QTR_ID'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Gaurav\Desktop\College\Sem_7_Assignments\ML\KMeansSales.ipynb Cell 26 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/Gaurav/Desktop/College/Sem_7_Assignments/ML/KMeansSales.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> # jinka zyada correlation hai unko remove karna hai
#       <a href='vscode-notebook-cell:/c%3A/Users/Gaurav/Desktop/College/Sem_7_Assignments/ML/KMeansSales.ipynb#X34sZmlsZQ%3D%3D?line=1'>2</a> # year_id and ordernumber & month_id and Qtr_id
#       <a href='vscode-notebook-cell:/c%3A/Users/Gaurav/Desktop/College/Sem_7_Assignments/ML/KMeansSales.ipynb#X34sZmlsZQ%3D%3D?line=2'>3</a> # remove year_id and qtr_id
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Gaurav/Desktop/College/Sem_7_Assignments/ML/KMeansSales.ipynb#X34sZmlsZQ%3D%3D?line=3'>4</a> df.drop(['YEAR_ID','QTR_ID'], axis=1, inplace=True)
#
# ...

# %%
# Now we will start K means clustering

# create a copy of df
dfk = df.copy()

# %%
# cleaning outliers as Kmeans is sensitive to outliers
# probable outliers can be in quantity ordered, price each, sales

def clean_outliers(data):
    ninety = np.percentile(data, 90)
    ten = np.percentile(data, 10)

    data = np.where(data >= ninety, ninety, data)
    data = np.where(data <= ten, ten, data)


outlier_columns = ['QUANTITYORDERED', 'PRICEEACH', 'SALES']
for col in outlier_columns:
    clean_outliers(dfk[col])

# %%
# Now we will do scaling on the data 
# scaling is done to bring all the data in the same range
# kmeans is based on euclidean distance, so we need to scale the data: to balance the data
# pure dataset ko scale karna hai


from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
dfk_scaled = scaler.fit_transform(dfk)
dfk_scaled
# Out:
# array([[-1.64794709, -0.52289086,  0.5969775 , ..., -0.16745383,
#         -0.34547029, -0.52337077],
#        [-1.4958875 , -0.11220131, -0.11445035, ..., -0.16745383,
#         -0.34547029, -0.52337077],
#        [-1.35468931,  0.60650538,  0.54938372, ..., -0.16745383,
#         -0.34547029, -0.52337077],
#        ...,
#        [ 1.38238338,  0.81185016,  0.81015797, ..., -0.16745383,
#         -0.34547029, -0.52337077],
#        [ 1.50185877, -0.11220131, -1.06186404, ..., -0.16745383,
#         -0.34547029, -0.52337077],
#        [ 1.68650256,  1.2225397 , -0.89925195, ..., -0.16745383,
#         -0.34547029, -0.52337077]])

# %%
# Using elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans

wcss = []
for i in range(1, 16):
    kmeans = KMeans(n_clusters=i) # i is the number of clusters
    kmeans.fit_predict(dfk_scaled) #apply kmeans on scaled data
    wcss.append(kmeans.inertia_) # inertia_ is the sum of squared distances of samples to their closest cluster center

wcss
# Out:
# C:\Users\Gaurav\AppData\Roaming\Python\Python310\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Gaurav\AppData\Roaming\Python\Python310\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# C:\Users\Gaurav\AppData\Roaming\Python\Python310\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
# plot the elbow graph
plt.plot(range(1, 16), wcss, marker='o')    
plt.title('The Elbow Graph')
plt.xlabel('Number of clusters')
plt.ylabel('Inertia')

plt.show()

# %%
# lets take number of clusters as 10
kmeans = KMeans(n_clusters=10, init='k-means++')
kmeans.fit_predict(dfk_scaled)
labels = kmeans.labels_

labels
# Out:
# C:\Users\Gaurav\AppData\Roaming\Python\Python310\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# array([5, 5, 5, ..., 9, 9, 9])

# %%
labels.size
# Out:
# 2823

# %%
# Heirarchical clustering
import scipy.cluster.hierarchy as sch

dendrogram = sch.dendrogram(sch.linkage(df, method='ward'))

# %%
# agglomerative clustering
from sklearn.cluster import AgglomerativeClustering

hc = AgglomerativeClustering(n_clusters=10, affinity='euclidean', linkage='ward')
labels = hc.fit_predict(df)

labels
# Out:
# C:\Users\Gaurav\AppData\Roaming\Python\Python310\site-packages\sklearn\cluster\_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# array([8, 8, 3, ..., 1, 9, 0], dtype=int64)
